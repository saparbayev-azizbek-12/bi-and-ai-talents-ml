# %% [markdown]
# ### Task 2: Gaussian Naive Bayes on Real-Valued Data

# %% [markdown]
# **Import packages**

# %%
import pandas as pd
import seaborn as sns
import sklearn.datasets as ds
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# **Step 1: Load the Iris dataset using sklearn.datasets.load_iris()**

# %%
iris_data = ds.load_iris()
iris_data['data'].shape
# Out:
# (150, 4)

# %% [markdown]
# **Step 2: Split the data into training and test sets (e.g., 70/30 split)**

# %%
X_train, X_test, y_train, y_test = train_test_split(iris_data['data'], iris_data['target'], test_size=0.30, random_state=42)
X_train.shape
# Out:
# (105, 4)

# %% [markdown]
# **Step 3: Initialize a GaussianNB model**

# %%
model = GaussianNB()
model = model.fit(X_train, y_train)

# %% [markdown]
# **Step 4: Train the model and evaluate performance using accuracy and classification report**

# %%
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
cls_report = classification_report(y_test, y_pred, target_names=iris_data.target_names, output_dict=True)

print("Accuracy:", accuracy)
print('Classification Report:', cls_report)
# Out:
# Accuracy: 0.9777777777777777
# Classification Report: {np.str_('setosa'): {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 19.0}, np.str_('versicolor'): {'precision': 1.0, 'recall': 0.9230769230769231, 'f1-score': 0.96, 'support': 13.0}, np.str_('virginica'): {'precision': 0.9285714285714286, 'recall': 1.0, 'f1-score': 0.9629629629629629, 'support': 13.0}, 'accuracy': 0.9777777777777777, 'macro avg': {'precision': 0.9761904761904763, 'recall': 0.9743589743589745, 'f1-score': 0.974320987654321, 'support': 45.0}, 'weighted avg': {'precision': 0.9793650793650793, 'recall': 0.9777777777777777, 'f1-score': 0.9777448559670782, 'support': 45.0}}

# %%
report_df = pd.DataFrame(cls_report).transpose().iloc[:3, :3]

plt.figure(figsize=(8, 6))
sns.heatmap(report_df, annot=True, cmap="YlGnBu", fmt=".2f")
plt.ylabel("Classes")
plt.xlabel("Metrics")
plt.show()
